# %% [markdown]
# ## Cleaning and Put to CSV file

# %%
import keras
import numpy as np
import pandas as pd
import os
import glob
import math
import re
df = tweets = pd.read_excel("./healthcareoutput.xlsx")
df = df[['TweetText','Polarity']]
def processRow(row):
    #Lower case
    tweet = row.lower()
    
    #delete any url
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
    #delete any @Username
    tweet = re.sub('@[^\s]+','',tweet) #
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    tweet = re.sub('[\n]+', ' ', tweet)
    #Remove not alphanumeric symbols white spaces
    tweet = re.sub(r'[^\w]', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    #Remove Digits
    tweet = re.sub(" \d+", '', tweet)
    tweet = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", tweet)
    #Remove :( or :)
    tweet = tweet.replace(':)','')
    tweet = tweet.replace(':(','')
    #trim
    tweet = tweet.strip('\'"')
    row = tweet
    return row

testing = np.array(list(df['TweetText'][:15000]))  
for x in range(0,testing.shape[0]):
    testing[x] = processRow(testing[x])
    
df_clean = df.copy()
df_clean.TweetText = testing
#df_clean.to_csv("clean_healthcaretweet.csv", index = False)
# Out:
# Using TensorFlow backend.

# %%
df
# Out:
#                                                TweetText  Polarity
# 0      @plambrechtsen Fyi, you can do the same in "Un...       0.0
# 1      China should be paying for the healthcare of a...      -1.0
# 2      @thetenderforlaw @megaholt There’s no lying ab...       1.0
# 3      @ChrisMurphyCT Chris \nThe incompetence, fake ...      -1.0
# 4      THANK YOU TO OUR NURSES!!! THE HEALTHCARE WORK...       0.0
# 5      CDC analysis shows coronavirus poses serious r...      -1.0
# 6      Hackers Promise 'No More Healthcare Cyber Atta...       1.0
# 7      SA’s healthcare system has only around 3 000 c...      -1.0
# 8      We've got a two tiered healthcare system: one ...       1.0
# 9      @republic Idiot,  he told government,hospitals...      -1.0
# 10     @DrHarjitBhatti Our PM launched a Clap, Beatin...       1.0
# 11     @rohini_sgh It’s for motivating and appreciati...      -1.0
# 12     @plambrechtsen And maybe being pushed through ...      -1.0
# 13     So much “goodness” right now in a time of sadn...       0.0
# 14     @LeeAckerson @Laurie_Garrett Italy gets a bad ...       1.0
# 15     The #tech on the frontlines of the fight again...       1.0
# 16     @DoritoHMA @divabarbieyyc @lhaukmee @UCP They ...       0.0
# 17     The CDC says healthcare workers who can't get ...       0.0
# 18     We are seriously running out of things!! We ar...       1.0
# 19     @MorningLiveSABC @SakinaKamwendo @LeanneManas ...       0.0
# 20     @Shehla_Rashid @barri_ismail @narendramodi It ...       0.0
# 21     @NationalNhi @DrZweliMkhize Good Morning Dr Mk...      -1.0
# 22     @ianstevensc @BravoExcelente @bluefyretyger @M...       1.0
# 23     Hospital Administrators: US Physicians/Healthc...       0.0
# 24     Not to be a huge dickwad but this is exactly w...       0.0
# 25     My heart is filled with gratitude. It is also ...       1.0
# 26     @senatemajldr @realDonaldTrump Healthcare care...       1.0
# 27     Something like universal healthcare, basic liv...       0.0
# 28     @curiouschinwag Right now, we need personal pr...       1.0
# 29     @WBTV_News Cant run a website but people think...       1.0
# ...                                                  ...       ...
# 14970  things i fuck with:\n- equal rights\n- healthc...       NaN
# 14971  ✳️READY TO SERVE OUR COUNTRY🇮🇪 @HSELive is cal...       NaN
# 14972  @MichaelVSmith3 @SIChrisMannix @SInow There ar...       NaN
# 14973  Wish it was nice out so I could at least quara...       NaN
# 14974  @catain_america @andres_0122 @WhyNotChaos @Par...       NaN
# 14975  @chrissyteigen I hate watching rich people pro...       NaN
# 14976  Boss told us we are still working to assist He...       NaN
# 14977  https://t.co/wRSs3eHhDG \n\nThe coronavirus st...       NaN
# 14978  @HillaryClinton @realDonaldTrump Thank you. He...       NaN
# 14979  Welcome spring, and the sunshine and vitamin D...       NaN
# 14980  Idk why someone didn’t stop me when I said I w...       NaN
# 14981  Exclusive: Nurse Tested for Coronavirus Claims...       NaN
# 14982  @thehill This idiot and his son in-law have pu...       NaN
# 14983  @johnatrevino1 @shoe0nhead joe championed the ...       NaN
# 14984  Be Proactive about your health and wellness in...       NaN
# 14985  i’m a healthcare worker please i’m begging you...       NaN
# 14986  I’m honestly just so thankful that i work in a...       NaN
# 14987  @AdoreMe Cozy! More comfy things to wear for p...       NaN
# 14988  @McginnKeven @WattzzD @marvin_hill123 @Jeanett...       NaN
# 14989  As usual, nagbabasa na naman siya. Di ko tuloy...       NaN
# 14990  @Sartre_vs_Sport WE ALL HAVE RESPONSIBILITIES ...       NaN
# 14991  Well at least shes willing to Help out with th...       NaN
# 14992  @washingtonpost #COVID19 is not doing enough. ...       NaN
# 14993  @keet0007 @jack_mcmurry @yourboynewguy @Johnat...       NaN
# 14994  @neeratanden We are getting shipments for all ...       NaN
# 14995  @AMoosaMD @EliaMPestana I am in Detroit right ...       NaN
# 14996  @viva_verde No, every other universal healthca...       NaN
# 14997  Ay Dios. Spain with 3,400 cases in a day and o...       NaN
# 14998  #AthleticTrainers across the country are stepp...       NaN
# 14999  If the healthcare system is overrun with COVID...       NaN
#
# [15000 rows x 2 columns]

# %% [markdown]
# ## Naive Bayes and SVM

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

#Set Random seed
np.random.seed(500)

# Add the Data using pandas
Corpus = pd.read_csv(r"clean_healthcaretweet.csv",encoding='latin-1')
Corpus['Polarity'] = Corpus['Polarity'].apply(str) #converts the float string into string/obj for processing
#print(Corpus.dtypes)

# Step - 1a : Tokenization : In this each entry in the corpus will be broken into set of words
Corpus['TweetText']= [word_tokenize(str(entry)) for entry in Corpus['TweetText']]
# Step - 1b: Perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
# Out:
# [nltk_data] Downloading package punkt to /home/hoang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/hoang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/hoang/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
for index,entry in enumerate(Corpus['TweetText']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus.loc[index,'text_final'] = str(Final_words)

print(Corpus['text_final'].head())
# Out:
# 0         ['fyi', 'univeral', 'healthcare', 'germany']
# 1    ['china', 'pay', 'healthcare', 'get', 'disease...
# 2    ['lie', 'healthcare', 'work', 'healthcare', 's...
# 3    ['chris', 'incompetence', 'fake', 'empathy', '...
# 4    ['thank', 'nurse', 'healthcare', 'worker', 'th...
# Name: text_final, dtype: object

# %%
# Step - 2: Split the model into Train and Test Data set
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus['text_final'],Corpus['Polarity'],test_size=0.2)

# Step - 3: Label encode the target variable  - This is done to transform Categorical data of string type in the data set into numerical values
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)
# Step - 4: Vectorize the words by using TF-IDF Vectorizer - This is done to find how important a word in document is in comaprison to the corpus
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(Corpus['text_final'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
# Step - 5: Now we can run different algorithms to classify out data check for accuracy

# Classifier - Algorithm - Naive Bayes
# fit the training dataset on the classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)


# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)

# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  82.39999999999999
# SVM Accuracy Score ->  82.43333333333334

# %%
set(Test_Y)
# Out:
# {0, 1, 2, 3}

# %%
set(predictions_SVM)
# Out:
# {0, 3}

# %%
result_dict = {'id': Test_X.id,
               'Text': df['TweetText'][df.index == Test_X.id],
               'target': SVM.predict(Test_X_Tfidf)}
submission = pd.DataFrame.from_dict(result_dict)
submission
# submission.to_csv('lr_submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ce4705f8aa70> in <module>()
# ----> 1 result_dict = {'id': Test_X.id,
#       2                'Text': df['TweetText'][df.index == Test_X.id],
#       3                'target': SVM.predict(Test_X_Tfidf)}
#       4 submission = pd.DataFrame.from_dict(result_dict)
#       5 submission
#
# /home/hoang/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'id'
